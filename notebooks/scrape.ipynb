# %% [markdown]
# ## Scrape collected URLs
#
# **Fields of interest**: Pub date, reporter name, reporter title, article hed, article dek, article text

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

from tqdm import tqdm

# %%
df = pd.read_csv('../data/COMPOSITE_29days.csv')

# %%
results = []
for i in tqdm(df.urls):
    r = requests.get(i)
    soup = BeautifulSoup(r.content)
    try:
        byline = soup.find('span', {'class': 'news-byline-full__name'}).get_text()
    except:
        byline = None
    try:
        title = soup.find('span', {'class': 'news-byline-full__role'}).get_text()
    except:
        title = None
    try:
        pub_date = soup.find('p', {'class': 'news-article-header__timestamps-posted'}).get_text()
    except:
        pub_date = None
    try:
        hed = soup.find('h1').get_text()
    except:
        hed = None
    try:
        dek = soup.find('p', {'class': 'news-article-header__dek'}).get_text()
    except:
        dek = None
    try:
        body = '\n'.join([i.get_text() for i in soup.find('div', {'class': 'js-article-wrapper'}).find_all(['h2', 'p'])])
    except:
        body = None
    res = {'byline': byline,
           'title': title,
           'pub_date': pub_date,
           'hed': hed,
           'dek': dek,
           'body': body}
    results.append(res)
# Out:
#   1%|▍                                                                             | 28/4666 [02:08<3:56:37,  3.06s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-be0a85b4c164> in <module>
#       1 results = []
#       2 for i in tqdm(df.urls):
# ----> 3     r = requests.get(i)
#       4     soup = BeautifulSoup(r.content)
#       5     try:
#
# ~\AppData\Local\Continuum\anaconda3\envs\buzzfeed_layoffs\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\AppData\Local\Continuum\anaconda3\envs\buzzfeed_layoffs\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ...

# %%
results_df = pd.DataFrame(results)

# %%
results_df.to_csv('../data/scraped_data.csv', index=False)

# %%
results_df = results_df[~results_df['pub_date'].isna()]

# %%
results_df['parsed_date'] = pd.to_datetime(results_df['pub_date'].apply(lambda x: x.split('Posted on ')[1].split(', at')[0]))
# Out:
# C:\Users\nrh146\AppData\Local\Continuum\anaconda3\envs\buzzfeed_layoffs\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
results_df[results_df['parsed_date']>pd.to_datetime('2018-12-31')].groupby('parsed_date').count()
# Out:
#              byline  title  pub_date  hed  dek  body
# parsed_date
# 2019-01-02        6      6         6    6    6     6
# 2019-01-03        2      2         2    2    2     2
# 2019-01-04        8      8         8    8    8     8
# 2019-01-05        2      2         2    2    2     2
# 2019-01-06        7      7         7    7    7     7
# 2019-01-07        5      5         5    5    5     5
# 2019-01-08       29     29        29   29   29    29
# 2019-01-09       15     15        15   15   15    15
# 2019-01-10       10     10        10   10   10    10
# 2019-01-11        7      7         7    7    7     7
# 2019-01-12        1      1         1    1    1     1
# 2019-01-13        1      1         1    1    1     1
# 2019-01-14        7      7         7    7    7     7
# 2019-01-15        9      9         9    9    9     9
# 2019-01-16        6      6         6    6    6     6
# 2019-01-17        9      9         9    9    9     9
# ...
